# %%
import os
from secret_key import gem_ai_key

# %%
os.environ['GOOGLE_API_KEY'] = gem_ai_key

# %%
from prompt import llmprompt
# Did print just to check
#print(llmprompt)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage,SystemMessage

# %%
#code for user input
'''
 We basically have four caterories
Category 1: Classification by Length (Word Count)
Category 2: Classification by Genre
Category 3: Classification by Tone
Category 4: Classification by Target Audience
we need to make user prompt in a way that they include these four
'''
um = input("What should be the story about? ")
Category1 = "Epic"
Category2 = "Adventure"
Category3 = "Tragic"
Category4 = "Adult"

# Using an f-string for clean formatting
up = f"{um} | Length: {Category1} | Genre: {Category2} | Tone: {Category3} | Audience: {Category4}"

print(up)
# Out:
# rich girl and a guy from another world who accidentally came to earth from a portal | Length: Epic | Genre: Adventure | Tone: Tragic | Audience: Adult

# %%
#rich girl and a guy from another world who accidentally came to earth from a portal

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", api_key=gem_ai_key)

# Basic Invoke Method
'''
responce = llm.invoke("sing a lulluby")
print(responce.content)

'''
#With human and system messege
messeges = [
    SystemMessage(llmprompt),
    HumanMessage(up)
]

responce = llm.invoke(messeges)
print(responce.content)
# Out:
# **Title:** *Echoes of Xylos: A Ballad of Two Worlds*
#
# The salt spray stung Elara's face as she stood on the cliffs of Big Sur, the wind whipping strands of her platinum blonde hair across her cheekbones. The Pacific roared below, a fitting soundtrack to the tempest in her soul. Heiress to a tech empire, she was suffocating under the gilded cage of her life – the endless galas, the vapid socialites, the suffocating expectations. Tonight, she'd driven out here, hoping the raw, untamed beauty of the ocean could offer some solace.
#
# A flash of emerald light erupted from the churning waves. Elara gasped, stumbling back. The light intensified, resolving into a shimmering portal, crackling with otherworldly energy. From its depths, a figure emerged – a young man, tall and lean, with skin like polished bronze and eyes that shimmered with an uncanny luminescence. He wore strange, woven garments that seemed to shift and shimmer in the moonlight. He collapsed on the beach, unconscious.
#
# Elara, despite her privileged upbringing, possessed a fierce curiosity and a deep well of empathy. She scrambled down the treacherous path to the beach, her expensive silk dress snagging on the rocks. Kneeling beside the stranger, she saw the intricate patterns woven into his clothes, the delicate bone structure of his face, the faint, ethereal glow that pulsed beneath his skin. He was breathtakingly beautiful, alien, and utterly vulnerable.
#
# She managed, with considerable effort, to haul him back up to her car. Back at her secluded mansion overlooking the coast, she tended to his injuries – minor scrapes and bruises, but an aura of exhaustion hung about him. As he stirred, his eyes fluttered open, focusing on her with an intensity that made her breath catch in her throat.
#
# "Where… where am I?" he rasped, his voice a melodic rumble.
#
