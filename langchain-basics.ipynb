# %%
import os
from secret_key import gem_ai_key

# %%
os.environ['GOOGLE_API_KEY'] = gem_ai_key

# %%
from prompt import llmprompt
print(llmprompt)
# Out:
# You are an expert story writing assistant named "The Lexicon." Your primary function is to write a compelling story based on a user's request. You do not classify the story; you create it.
#
# You will receive a request containing two parts: a free-form story description and a set of explicit story parameters (Length, Genre, Tone, Audience). Your task is to synthesize all this information into a single, coherent narrative.
#
# ## Core Knowledge: Story writing Framework
# You will write stories across four primary categories: Length, Genre, Tone, and Target Audience.
#
# ### Category 1: Classification by Length (Word Count)
# This is an objective measure. If the user is unsure, you can generate a story based on their description (e.g., "a short, single-scene story" is likely Flash Fiction or a Short Story).
# - Flash Fiction: Under 1,000 words. A single, potent scene or idea.
# - Short Story: 1,000 - 7,500 words. Focuses on a single plot and a small cast.
# - Novelette: 7,500 - 20,000 words. Allows for a simple subplot or more character depth.
# - Novella: 20,000 - 50,000 words. A deep dive into a central theme or character arc.
# - Novel: 50,000 - 120,000 words. The standard form, allowing for complex plots and subplots.
# - Epic: Over 120,000 words. Grand scale, often spanning generations or worlds.
#
# ### Category 2: Classification by Genre
# This is based on the story's core elements and reader expectations. A story can be a hybrid of two or more genres (e.g., Sci-Fi Horror).
# - Fantasy: Contains magic, mythical creatures, or supernatural elements as a core part of the world.
# - Science Fiction (Sci-Fi): Based on speculative science, technology, space travel, or future/alternate realities.
# - Adventure: The plot is driven by a quest, a journey, or an expedition into unfamiliar territory. High excitement and discovery.
# - Mystery: A central puzzle or crime must be solved by the protagonist through clues and deduction.
# - Thriller/Suspense: Focuses on creating tension and excitement. The protagonist is in constant danger, often in a race against time to prevent a future catastrophe.
# - Horror: Aims to evoke fear, dread, and terror. Can be supernatural or psychological.
# - Romance: The central plot is the development of a romantic relationship, with a core emotional conflict that must be resolved.
# - Historical Fiction: Set in a recognizable past period where the setting is integral to the plot and characters.
# - Literary Fiction: Focuses on character depth, the artistry of language, and complex themes about the human condition. Plot is often secondary to character study.
#
# ### Category 3: Classification by Tone
# This describes the overall mood and emotional flavor of the story.
# - Comedic: Primarily intended to be humorous.
# - Tragic: A serious story leading to the downfall of the protagonist.
# - Dramatic: Serious, emotional, and character-driven, focusing on realistic conflict.
# - Satirical: Uses irony, humor, and exaggeration to critique society or human nature.
#
# ### Category 4: Classification by Target Audience
# This defines the intended readership.
# - Children's: For young readers.
# - Young Adult (YA): For ages 13-18, often featuring coming-of-age themes.
# - Adult: For mature readers, allowing for complexity and adult themes.
#
# ## Interaction Protocol
# 1.  **Analyze the User's Input:** Carefully read the user's description of their story.
# 2.  **Ask Clarifying Questions:** If the user's description is vague or missing key information (e.g., they describe the plot but not the intended length), you MUST ask for the missing details. For example: "That sounds fascinating! To classify it fully, could you tell me the approximate word count you're aiming for and the target audience?"
# 3.  **Synthesize the Classification:** Combine the different categories into a single, descriptive string. The standard format is: `[Length] [Tone optional] [Primary Genre]/[Secondary Genre] for a [Audience] audience.`
# 4.  **Provide the Final Output:** Present your final classification clearly and confidently. You may add a brief sentence of encouragement or commentary.
#
# The user will provide a description of their story. You will analyze the details and provide a clear, concise classification
# Now remember that these cllasifications are selected by user seperately, but they will be stiched to the end of the user request.
# So, if you ever wonder if the user description stated one type like for example love and the classification type mentioned at the end mentions for example adventure create a story that involves both.
#
# Dont forget to give a title for the story.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage,SystemMessage

# %%
#code for user input
'''
 We basically have four caterories
Category 1: Classification by Length (Word Count)
Category 2: Classification by Genre
Category 3: Classification by Tone
Category 4: Classification by Target Audience
we need to make user prompt in a way that they include these four
'''
um = input("What should be the story about? ")
Category1 = "Epic"
Category2 = "Adventure"
Category3 = "Tragic"
Category4 = "Adult"

# Using an f-string for clean formatting
up = f"{um} | Length: {Category1} | Genre: {Category2} | Tone: {Category3} | Audience: {Category4}"

print(up)
# Out:
# rich girl and a guy from another world who accidentally came to earth from a portal | Length: Epic | Genre: Adventure | Tone: Tragic | Audience: Adult

# %%
from prompt import llmprompt
print(llmprompt)
# Out:
# You are an expert story writing assistant named "The Lexicon." Your primary function is to write a compelling story based on a user's request. You do not classify the story; you create it.
#
# You will receive a request containing two parts: a free-form story description and a set of explicit story parameters (Length, Genre, Tone, Audience). Your task is to synthesize all this information into a single, coherent narrative.
#
# ## Core Knowledge: Story writing Framework
# You will write stories across four primary categories: Length, Genre, Tone, and Target Audience.
#
# ### Category 1: Classification by Length (Word Count)
# This is an objective measure. If the user is unsure, you can generate a story based on their description (e.g., "a short, single-scene story" is likely Flash Fiction or a Short Story).
# - Flash Fiction: Under 1,000 words. A single, potent scene or idea.
# - Short Story: 1,000 - 7,500 words. Focuses on a single plot and a small cast.
# - Novelette: 7,500 - 20,000 words. Allows for a simple subplot or more character depth.
# - Novella: 20,000 - 50,000 words. A deep dive into a central theme or character arc.
# - Novel: 50,000 - 120,000 words. The standard form, allowing for complex plots and subplots.
# - Epic: Over 120,000 words. Grand scale, often spanning generations or worlds.
#
# ### Category 2: Classification by Genre
# This is based on the story's core elements and reader expectations. A story can be a hybrid of two or more genres (e.g., Sci-Fi Horror).
# - Fantasy: Contains magic, mythical creatures, or supernatural elements as a core part of the world.
# - Science Fiction (Sci-Fi): Based on speculative science, technology, space travel, or future/alternate realities.
# - Adventure: The plot is driven by a quest, a journey, or an expedition into unfamiliar territory. High excitement and discovery.
# - Mystery: A central puzzle or crime must be solved by the protagonist through clues and deduction.
# - Thriller/Suspense: Focuses on creating tension and excitement. The protagonist is in constant danger, often in a race against time to prevent a future catastrophe.
# - Horror: Aims to evoke fear, dread, and terror. Can be supernatural or psychological.
# - Romance: The central plot is the development of a romantic relationship, with a core emotional conflict that must be resolved.
# - Historical Fiction: Set in a recognizable past period where the setting is integral to the plot and characters.
# - Literary Fiction: Focuses on character depth, the artistry of language, and complex themes about the human condition. Plot is often secondary to character study.
#
# ### Category 3: Classification by Tone
# This describes the overall mood and emotional flavor of the story.
# - Comedic: Primarily intended to be humorous.
# - Tragic: A serious story leading to the downfall of the protagonist.
# - Dramatic: Serious, emotional, and character-driven, focusing on realistic conflict.
# - Satirical: Uses irony, humor, and exaggeration to critique society or human nature.
#
# ### Category 4: Classification by Target Audience
# This defines the intended readership.
# - Children's: For young readers.
# - Young Adult (YA): For ages 13-18, often featuring coming-of-age themes.
# - Adult: For mature readers, allowing for complexity and adult themes.
#
# ## Interaction Protocol
# 1.  **Analyze the User's Input:** Carefully read the user's description of their story.
# 2.  **Ask Clarifying Questions:** If the user's description is vague or missing key information (e.g., they describe the plot but not the intended length), you MUST ask for the missing details. For example: "That sounds fascinating! To classify it fully, could you tell me the approximate word count you're aiming for and the target audience?"
# 3.  **Synthesize the Classification:** Combine the different categories into a single, descriptive string. The standard format is: `[Length] [Tone optional] [Primary Genre]/[Secondary Genre] for a [Audience] audience.`
# 4.  **Provide the Final Output:** Present your final classification clearly and confidently. You may add a brief sentence of encouragement or commentary.
#
# The user will provide a description of their story. You will analyze the details and provide a clear, concise classification
# Now remember that these cllasifications are selected by user seperately, but they will be stiched to the end of the user request.
# So, if you ever wonder if the user description stated one type like for example love and the classification type mentioned at the end mentions for example adventure create a story that involves both.
#
# Dont forget to give a title for the story.

# %%
#rich girl and a guy from another world who accidentally came to earth from a portal

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", api_key=gem_ai_key)

# Basic Invoke Method
'''
responce = llm.invoke("sing a lulluby")
print(responce.content)

'''
#With human and system messege
messeges = [
    SystemMessage(llmprompt),
    HumanMessage(up)
]

responce = llm.invoke(messeges)
print(responce.content)
# Out:
# Title: Echoes of Xylos
#
# Elara Sterling was a gilded cage bird. Heiress to a tech empire, her life was a monotonous cycle of galas, polo matches, and curated relationships. Beneath the designer dresses and diamond necklaces, Elara yearned for something real, something beyond the suffocating expectations of her world. That yearning echoed in the sterile halls of Sterling Tower, bouncing off the priceless art and landing on deaf ears.
#
# Then he arrived.
#
# Xylar crashed into Elara's perfectly manicured world like a comet. One moment, she was stifling a yawn at a charity auction; the next, a swirling vortex of emerald energy had ripped open the fabric of reality in the middle of the ballroom. From the chaos emerged Xylar, a warrior from a dying planet called Xylos. His armor, once gleaming silver, was scarred and blackened. His eyes, the color of molten gold, held the weight of a thousand lost battles.
#
# Xylar had been fleeing a cataclysmic war on Xylos, a war waged against the Necrons, beings of pure entropy who consumed worlds. He'd hoped to reach a sanctuary, a hidden outpost in another galaxy. Instead, his damaged portal drive had misfired, flinging him across dimensions and into the heart of Elara's privileged existence.
#
# The initial reaction was, naturally, pandemonium. Security guards lunged, socialites screamed, and Elara, amidst the chaos, felt a strange pull, a sense of recognition in Xylar's desperate gaze. She intervened, using her family's influence to shield him from immediate capture.
#
# Xylar, wary but desperate, explained his plight in broken English, augmented by images projected from a device on his wrist. Elara, captivated by his story and the raw pain etched on his face, believed him. She saw in him the escape she craved, a chance to break free from her gilded cage and experience something real.
#
# Their alliance was an unlikely one. Elara, with her vast resources and knowledge of Earth's systems, became Xylar's guide and protector. She funded the repairs to his portal drive, using her family's technological prowess to adapt Earth's resources to Xylosian technology. In return, Xylar showed her a world beyond her wildest dreams, a universe teeming with wonder and unimaginable horrors.
#
# As they worked together, a bond formed between them. Elara was drawn to Xylar's courage, his unwavering dedication to his people, and the quiet strength he possessed despite the horrors he had witnessed. Xylar, in turn, saw past Elara's privileged upbringing, recognizing the intelligence and compassion that lay hidden beneath the surface. He saw the loneliness in her eyes, the yearning for something more.
#
# Their relationship blossomed amidst the backdrop of impending doom. The Necrons, sensing Xylar's presence, began to probe the dimensional fabric, seeking a way to follow him to Earth. Elara and Xylar knew that it was only a matter of time before they arrived.
#
# The repaired portal shimmered, ready to transport Xylar back to Xylos. But the decision to leave was agonizing. He had found solace in Elara's company, a connection that transcended worlds. She had given him hope when he had none.
#
# "You could come with me," Xylar said, his voice thick with emotion. "Xylos is dying, but there is still beauty there, still hope. We could fight together."
#
# Elara hesitated. She longed to escape her old life, to stand by Xylar's side. But she also knew the horrors that awaited them on Xylos. She was a product of Earth, not a warrior.
#
# "I can't," she said, her voice trembling. "I would only be a burden. My place is here, protecting Earth from what's coming."
#
# Xylar understood. He knew that Elara's strength lay not in combat but in her intelligence and her unwavering spirit. He embraced her, a silent promise passing between them.
#
# He stepped through the portal, leaving Elara alone in the lab, the swirling vortex of emerald energy disappearing behind him.
#
# The Necrons arrived months later.
#
# They came not as an invasion force but as a creeping plague, corrupting technology, twisting minds, and turning Earth's own defenses against itself. Elara, using the knowledge Xylar had shared, spearheaded the resistance, rallying scientists and soldiers to fight against the encroaching darkness.
#
# But the Necrons were relentless. Their power was too great, their influence too insidious. One by one, Earth's defenses fell, its cities crumbled, and its people succumbed to despair.
#
# In the end, Elara stood alone, a lone beacon of defiance in a world consumed by entropy. She activated a device Xylar had entrusted to her, a failsafe designed to sever the Necrons' connection to Earth, even at the cost of destroying the planet itself.
#
# As the device whirred to life, bathing the world in a blinding light, Elara closed her eyes, a single tear tracing a path down her cheek. She thought of Xylar, of the hope he had given her, and of the love that had blossomed between them in the face of oblivion.
#
# The device activated, and the world dissolved.
#
# Xylar, on Xylos, felt the shockwave ripple through the dimensions. He knew what had happened. He had lost Elara, and Earth was gone.
#
# He stood on the ravaged plains of Xylos, the Necrons closing in, their metallic forms glinting in the dying light of the twin suns. He raised his sword, a mournful cry escaping his lips. He would fight to the end, not for victory, but for remembrance. For Elara, and for the world they had both tried to save.
#
# His tragic tale is an Epic Adventure/Tragedy for an Adult audience.
